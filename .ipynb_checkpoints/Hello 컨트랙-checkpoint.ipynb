# %% [markdown]
# ## 문제
# Hello 컨트랙을 수정하여, 인사하는 대상을 지정해보자.
#
# * 멤버변수에는 toWhom을 지정한다.
#
# * 멤버함수에는 아래 함수를 구현한다. 일부러 함수의 입출력 인자는 생략하니 자신이 생각해서 구현한다.
#
# ```
#
# function sayHello() view public returns() 입력: 없다, 출력: Hello smu (bytes 또는 string로 출력)
#
# function setWhom() public 입력: 인사하는 대상 (toWhom을 지정, bytes 또는 string로 입력)
#
# function getWhom() view public returns() 출력: 인사하는 대상 (toWhom을 읽음, bytes 또는 string로 출력)
#
# ```
#
#
#
# 문자열 합성을 하려면, 이전에는 abi.encodePacked()를 함수를 사용했으나 버전 0.8.10부터 bytes.concat() 또는 string.concat() 함수를 사용하면 된다.
#
#
#
# 각 각 2개의 컨트랙을 구현한다 - HelloInString.sol, HelloInBytes.sol.
#
# * (1) REMIX에서 실행하고, 각 함수의 로그 결과를 붙여넣기한다 (입력, 출력, gas가 보이도록).
#
# * (2) HelloInString과 HelloInBytes의 배포할 때와 sayHello() 함수의 gas를 비교하세요.

# %%
# %%writefile HelloInString.sol
# //SPDX-License-Identifier: GPL-3.0-or-later
# pragma solidity ^0.8.0;
#
# contract HelloInString {
#
#     string toWhom = "smu";
#     string h = "Hello ";
#
#     function setWhom(string memory Whom) public {
#         toWhom = Whom;
#     }
#
#     function getWhom() view public returns(string memory){
#         return toWhom;
#     }
#
#     function sayHello(string memory) view public returns(string memory) {
#
#         return string.concat(h,toWhom);
#     }
# }
# Out:
# Writing HelloInString.sol

# %% [markdown]
# deploy 할때 :
#
# [vm]from: 0x5B3...eddC4to: HelloInString.(constructor)value: 0 weidata: 0x608...d0033logs: 0hash: 0x41c...71a33
# status	true Transaction mined and execution succeed
# transaction hash	0x41c055590f4f1f95e3e0a56a9029b99dbab5efcf4f46afc45d558df3f2071a33
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
# to	HelloInString.(constructor)
# gas	488515 gas
# transaction cost	424795 gas
# execution cost	424795 gas
# input	0x608...d0033
# decoded input	{}
# decoded output	 -
# logs	[]
# val	0 wei

# %% [markdown]
# setWhom 함수 :
#
# [vm]from: 0x5B3...eddC4to: HelloInString.setWhom(string) 0xd7C...faC5Fvalue: 0 weidata: 0x1c8...00000logs: 0hash: 0xd52...8e1f7
# status	true Transaction mined and execution succeed
#
#
# transaction hash	0xd52a82b0765b5251939f8e2eda4736e00696ca52386fe5b3816e0f68aa78e1f7
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	HelloInString.setWhom(string) 0xd7Ca4e99F7C171B9ea2De80d3363c47009afaC5F
#
# gas	28554 gas
#
# transaction cost	24829 gas
#
# execution cost	24829 gas
#
# input	0x1c8...00000
#
# decoded input	{
# 	"string Whom": ""
# }
#
# decoded output	{}
#
# logs	[]
#
# val	0 wei

# %% [markdown]
# getWhom 함수 :
# CALL
# [call]from: 0x5B38Da6a701c568545dCfcB03FcB875f56beddC4to: HelloInString.getWhom()data: 0x3c5...00c0e
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	HelloInString.getWhom() 0xd7Ca4e99F7C171B9ea2De80d3363c47009afaC5F
#
# execution cost	24521 gas (Cost only applies when called by a contract)
#
# input	0x3c5...00c0e
#
# decoded input	{}
#
# decoded output	{
# 	"0": "string: smu"
# }
#
# logs	[]

# %% [markdown]
# sayHello 함수 :
# CALL
# [call]from: 0x5B38Da6a701c568545dCfcB03FcB875f56beddC4to: HelloInString.sayHello(string)data: 0xc3a...00000
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	HelloInString.sayHello(string) 0xd7Ca4e99F7C171B9ea2De80d3363c47009afaC5F
#
# execution cost	27793 gas (Cost only applies when called by a contract)
#
# input	0xc3a...00000
#
# decoded input	{
# 	"string ": ""
# }
#
# decoded output	{
# 	"0": "string: Hello smu"
# }
#
# logs	[]

# %%
# %%writefile HelloInString.sol
# //SPDX-License-Identifier: GPL-3.0-or-later
# pragma solidity ^0.8.13;
#
# contract HelloInBytes {
#
#     bytes toWhom = "smu";
#     bytes h = "Hello ";
#
#     function setWhom() public {
#         toWhom = toWhom;
#     }
#
#     function getWhom() public view returns(bytes memory) {
#         return toWhom;
#     }
#
#     function sayHello(bytes memory) view public returns(bytes memory) {
#
#         return bytes.concat(h, toWhom);
#     }
# }
# Out:
# Overwriting HelloInString.sol

# %% [markdown]
# deploy 할때:
#
# [vm]from: 0x5B3...eddC4to: HelloInString.(constructor)value: 0 weidata: 0x608...d0033logs: 0hash: 0x47c...e7552
# status	true Transaction mined and execution succeed
#
# transaction hash	0x47cfbdd58c97c8b13434772602c972d53f493eedeb1e4ab156e64081a99e7552
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	HelloInString.(constructor)
#
# gas	486265 gas
#
# transaction cost	422839 gas
#
# execution cost	422839 gas
#
# input	0x608...d0033
#
# decoded input	{}
#
# decoded output	 -
#
# logs	[]
#
# val	0 wei

# %% [markdown]
# setWhom 함수 :
#
# [vm]from: 0x5B3...eddC4to: HelloInString.(fallback) 0x2E9...b28e3value: 0 weidata: 0xf26...59c30logs: 0hash: 0xccd...13875
#
# status	true Transaction mined and execution succeed
#
# transaction hash	0xccdf0db4ab05233d172c4b60bafd3302dabd490dce4cd9c7259bda7a56113875
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	HelloInString.(fallback) 0x2E9d30761DB97706C536A112B9466433032b28e3
#
# gas	30358 gas
#
# transaction cost	26398 gas
#
# execution cost	26398 gas
#
# input	0xf26...59c30
#
# decoded input	-
#
# decoded output	 -
#
# logs	[]
#
# val	0 wei

# %% [markdown]
# getWhom 함수 :
#
# CALL
# [call]from: 0x5B38Da6a701c568545dCfcB03FcB875f56beddC4to: HelloInString.getWhom()data: 0x3c5...00c0e
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	HelloInString.getWhom() 0x9a2E12340354d2532b4247da3704D2A5d73Bd189
#
# execution cost	24499 gas (Cost only applies when called by a contract)
#
# input	0x3c5...00c0e
#
# decoded input	{}
#
# decoded output	{
# 	"0": "string: smu"
# }
#
# logs	[]

# %% [markdown]
# sayHello 함수 :
#
# CALL
# [call]from: 0x5B38Da6a701c568545dCfcB03FcB875f56beddC4to: HelloInString.(fallback)data: 0xbf1...00000
#
# from	0x5B38Da6a701c568545dCfcB03FcB875f56beddC4
#
# to	HelloInString.(fallback) 0x2E9d30761DB97706C536A112B9466433032b28e3
#
# execution cost	27953 gas (Cost only applies when called by a contract)
#
# input	0xbf1...00000
#
# decoded input	-
#
# decoded output	 -
#
# logs	[]

# %% [markdown]
# ### (2) HelloInString과 HelloInBytes의 배포할 때와 sayHello() 함수의 gas를 비교하세요.
#
#
# #### HelloInString에서의 gas : 27793 gas
#
# #### HelloInBYtes에서의 gas : 27953 gas
#
#
# #### HelloInBytes가 169gas가 더 큽니다
